# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ls results_1
# Out:
# hist.npy       nongreedy.png

# %%
# non-binary, non e-greedy, 
raw_1 = np.load('./results_1/hist.npy'), './results_1'

# binary, non e-greedy
raw_2 = np.load('./results_2/hist.npy'), './results_2'

# non-binary, e-greedy
raw_3 = np.load('./results_3/hist-1.npy'), './results_3'

# non-binary, non e-greedy

# %%
data, path = raw_1

# other info
for i, x in enumerate(data):
    if x > 100:
        print('reach 100 ', i)
        break
    
        
print('max ', max(data))

# raw
plt.plot(data)
plt.title('plot of score vs # of iterations')
plt.ylabel('score')
plt.xlabel('# of iteration')
plt.savefig(path + '/raw', dpi=300)
plt.show()

# maximums
maxes = np.array([max(data[:i]) for i in range(1, len(data))])
plt.plot(maxes)
plt.title('plot of maximum score vs # of iterations')
plt.ylabel('score')
plt.xlabel('# of iteration')
plt.savefig(path + '/raw_max', dpi=300)
plt.show()
# Out:
# reach 100  58
# max  188
